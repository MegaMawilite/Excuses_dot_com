# %% [markdown]
# # Your First RNN
#
# **Exercise objectives**:
#
# - Better understand temporal data
# - Build your first Recurrent Neural Network
#
#
# <hr>
# <hr>

# %% [markdown]
# ## 1. The data
#
# Let's start with simple sequences of observations:

# %%
from tensorflow import keras
import numpy as np

# %%
#Load the files X.sav and Y.sav and store them in two arrays X and y
X = np.load('X.sav', allow_pickle=True)
y = np.load('Y.sav', allow_pickle=True)

# %%
#pip list
# Out:
# Package                        Version              Location
# ------------------------------ -------------------- ---------------------------------------------------
# absl-py                        1.4.0
# aenum                          3.1.5
# aiohttp                        3.8.1
# aiosignal                      1.2.0
# alabaster                      0.7.12
# altair                         4.2.0
# anaconda-client                1.9.0
# anaconda-navigator             2.3.1
# anaconda-project               0.10.2
# ansi2html                      1.8.0
# anyio                          3.5.0
# appdirs                        1.4.4
# argon2-cffi                    21.3.0
# argon2-cffi-bindings           21.2.0
# arrow                          1.2.2
# astroid                        2.6.6
# astropy                        5.0.4
# asttokens                      2.0.5
# astunparse                     1.6.3
# async-generator                1.10
# async-timeout                  4.0.1
# atomicwrites                   1.4.0
# attrs                          21.4.0
# Automat                        20.2.0
# autopep8                       1.6.0
# azure-cognitiveservices-speech 1.25.0
# azure-core                     1.26.3
# azure-storage-blob             12.15.0
# Babel                          2.9.1
# backcall                       0.2.0
# backports.functools-lru-cache  1.6.4
# backports.tempfile             1.0
# backports.weakref              1.0.post1
# bayesian-optimization          1.4.2
# bcrypt                         3.2.0
# beautifulsoup4                 4.11.1
# binaryornot                    0.4.4
# bitarray                       2.4.1
# bkcharts                       0.2
# black                          19.10b0
# bleach                         4.1.0
# blinker                        1.5
# bokeh                          2.4.2
# boto3                          1.21.32
# botocore                       1.24.32
# Bottleneck                     1.3.4
# Brotli                         1.0.9
# brotlipy                       0.7.0
# cachetools                     4.2.2
# certifi                        2021.10.8
# cffi                           1.15.0
# chardet                        4.0.0
# charset-normalizer             2.0.7
# click                          8.0.3
# cloudpickle                    2.0.0
# clyent                         1.2.2
# colorama                       0.4.6
# colorcet                       2.0.6
# commonmark                     0.9.1
# comtypes                       1.1.10
# conda                          22.11.1
# conda-build                    3.21.8
# conda-content-trust            0+unknown
# conda-pack                     0.6.0
# conda-package-handling         1.8.1
# conda-repo-cli                 1.0.4
# conda-token                    0.3.0
# conda-verify                   3.4.2
# constantly                     15.1.0
# cookiecutter                   1.7.3
# coverage                       6.5.0
# cryptography                   3.4.8
# cssselect                      1.1.0
# cycler                         0.11.0
# Cython                         0.29.28
# cytoolz                        0.11.0
# daal4py                        2021.5.0
# dash                           2.6.2
# dash-core-components           2.0.0
# dash-html-components           2.0.0
# dash-table                     5.0.0
# dask                           2022.2.1
# datashader                     0.13.0
# datashape                      0.5.4
# dbf                            0.99.1
# debugpy                        1.5.1
# decorator                      5.1.1
# defusedxml                     0.7.1
# diff-match-patch               20200713
# discord.py                     2.1.0
# DiscordUtils                   1.3.4
# distributed                    2022.2.1
# docutils                       0.19
# entrypoints                    0.4
# et-xmlfile                     1.1.0
# exceptiongroup                 1.1.0
# executing                      0.8.3
# fastjsonschema                 2.15.1
# filelock                       3.6.0
# flake8                         3.9.2
# Flask                          2.0.2
# Flask-Compress                 1.13
# flaskr                         1.0.0                c:\users\utilisateur\desktop\briefs\10.gears museum
# flatbuffers                    23.3.3
# fonttools                      4.25.0
# frozenlist                     1.2.0
# fsspec                         2022.2.0
# furo                           2022.12.7
# future                         0.18.2
# gast                           0.4.0
# gensim                         4.1.2
# gitdb                          4.0.10
# GitPython                      3.1.29
# glob2                          0.7
# google-api-core                1.25.1
# google-auth                    1.33.0
# google-auth-oauthlib           0.4.6
# google-cloud-core              1.7.1
# google-cloud-storage           1.31.0
# google-crc32c                  1.1.2
# google-pasta                   0.2.0
# google-resumable-media         1.3.1
# googleapis-common-protos       1.53.0
# greenlet                       1.1.1
# grpcio                         1.42.0
# h11                            0.14.0
# h5py                           3.6.0
# HeapDict                       1.0.1
# holoviews                      1.14.8
# hvplot                         0.7.3
# hyperlink                      21.0.0
# idna                           3.3
# imagecodecs                    2021.8.26
# imageio                        2.9.0
# imagesize                      1.3.0
# importlib-metadata             4.11.3
# incremental                    21.3.0
# inflection                     0.5.1
# iniconfig                      1.1.1
# intake                         0.6.5
# intervaltree                   3.1.0
# ipykernel                      6.9.1
# ipython                        8.2.0
# ipython-genutils               0.2.0
# ipywidgets                     7.6.5
# isodate                        0.6.1
# isort                          5.9.3
# itemadapter                    0.3.0
# itemloaders                    1.0.4
# itsdangerous                   2.0.1
# jdcal                          1.4.1
# jedi                           0.18.1
# Jinja2                         3.0.2
# jinja2-time                    0.2.0
# jmespath                       0.10.0
# joblib                         1.1.0
# json5                          0.9.6
# jsonschema                     4.4.0
# jupyter                        1.0.0
# jupyter-client                 6.1.12
# jupyter-console                6.4.0
# jupyter-core                   4.9.2
# jupyter-dash                   0.4.2
# jupyter-server                 1.13.5
# jupyterlab                     3.3.2
# jupyterlab-pygments            0.1.2
# jupyterlab-server              2.10.3
# jupyterlab-widgets             1.0.0
# jupytext                       1.14.1
# keras                          2.11.0
# keyring                        23.4.0
# kiwisolver                     1.3.2
# lazy-object-proxy              1.6.0
# libarchive-c                   2.9
# libclang                       15.0.6.1
# llvmlite                       0.38.0
# locket                         0.2.1
# lxml                           4.8.0
# Markdown                       3.3.4
# markdown-it-py                 2.1.0
# MarkupSafe                     2.0.1
# matplotlib                     3.5.1
# matplotlib-inline              0.1.2
# mccabe                         0.6.1
# mdit-py-plugins                0.3.1
# mdurl                          0.1.2
# menuinst                       1.4.18
# mistune                        0.8.4
# mizani                         0.8.1
# mkl-fft                        1.3.1
# mkl-random                     1.2.2
# mkl-service                    2.4.0
# mock                           4.0.3
# mpmath                         1.2.1
# msgpack                        1.0.2
# multidict                      5.1.0
# multipledispatch               0.6.0
# munkres                        1.1.4
# mypy-extensions                0.4.3
# navigator-updater              0.2.1
# nbclassic                      0.3.5
# nbclient                       0.5.13
# nbconvert                      6.4.4
# nbformat                       5.3.0
# nest-asyncio                   1.5.5
# networkx                       2.7.1
# nltk                           3.7
# nose                           1.3.7
# notebook                       6.4.8
# numba                          0.55.1
# numexpr                        2.8.1
# numpy                          1.21.3
# numpydoc                       1.2
# oauthlib                       3.2.2
# olefile                        0.46
# openai                         0.19.0
# openpyxl                       3.0.9
# opt-einsum                     3.3.0
# outcome                        1.2.0
# packaging                      21.3
# palettable                     3.3.0
# pandas                         1.3.4
# pandas-stubs                   1.2.0.35
# pandocfilters                  1.5.0
# panel                          0.13.0
# param                          1.12.0
# paramiko                       2.8.1
# parsel                         1.6.0
# parso                          0.8.3
# partd                          1.2.0
# pathspec                       0.7.0
# patsy                          0.5.2
# pep8                           1.7.1
# pexpect                        4.8.0
# pickleshare                    0.7.5
# Pillow                         9.0.1
# pip                            21.2.4
# pkginfo                        1.8.2
# plotly                         5.6.0
# plotnine                       0.10.1
# pluggy                         1.0.0
# pmdarima                       2.0.2
# poyo                           0.5.0
# prometheus-client              0.13.1
# prompt-toolkit                 3.0.20
# Protego                        0.1.16
# protobuf                       3.19.1
# psutil                         5.8.0
# ptyprocess                     0.7.0
# pure-eval                      0.2.2
# py                             1.11.0
# pyarrow                        10.0.1
# pyasn1                         0.4.8
# pyasn1-modules                 0.2.8
# pycodestyle                    2.8.0
# pycosat                        0.6.3
# pycparser                      2.21
# pyct                           0.4.6
# pycurl                         7.44.1
# pydeck                         0.8.0
# PyDispatcher                   2.0.5
# pydocstyle                     6.1.1
# pyerfa                         2.0.0
# pyflakes                       2.3.1
# Pygments                       2.14.0
# PyHamcrest                     2.0.2
# PyJWT                          2.1.0
# pylint                         2.9.6
# pyls-spyder                    0.4.0
# Pympler                        1.0.1
# PyNaCl                         1.4.0
# pyodbc                         4.0.32
# pyOpenSSL                      21.0.0
# pyparsing                      3.0.4
# pyreadline                     2.1
# pyrsistent                     0.18.0
# PySocks                        1.7.1
# pytest                         7.1.1
# python-certifi-win32           1.6.1
# python-dateutil                2.8.2
# python-dotenv                  0.19.2
# python-lsp-black               1.0.0
# python-lsp-jsonrpc             1.0.0
# python-lsp-server              1.2.4
# python-slugify                 5.0.2
# python-snappy                  0.6.0
# pytz                           2021.3
# pytz-deprecation-shim          0.1.0.post0
# pyviz-comms                    2.0.2
# PyWavelets                     1.3.0
# pywin32                        302
# pywin32-ctypes                 0.2.0
# pywinpty                       2.0.2
# PyYAML                         6.0
# pyzmq                          22.3.0
# QDarkStyle                     3.0.2
# qstylizer                      0.1.10
# QtAwesome                      1.0.3
# qtconsole                      5.3.0
# QtPy                           2.0.1
# queuelib                       1.5.0
# regex                          2022.3.15
# requests                       2.26.0
# requests-file                  1.5.1
# requests-oauthlib              1.3.1
# retrying                       1.3.3
# rich                           12.6.0
# rope                           0.22.0
# rsa                            4.7.2
# Rtree                          0.9.7
# ruamel.yaml                    0.17.21
# ruamel.yaml.clib               0.2.6
# ruamel-yaml-conda              0.15.100
# s3transfer                     0.5.0
# scikit-image                   0.19.2
# scikit-learn                   1.0.2
# scikit-learn-intelex           2021.20220215.102710
# scipy                          1.7.3
# Scrapy                         2.6.1
# seaborn                        0.11.2
# selenium                       4.7.2
# semver                         2.13.0
# Send2Trash                     1.8.0
# service-identity               18.1.0
# setuptools                     61.2.0
# setuptools-scm                 7.1.0
# simpledbf                      0.2.6
# sip                            4.19.13
# six                            1.16.0
# slicer                         0.0.7
# smart-open                     5.1.0
# smmap                          5.0.0
# sniffio                        1.2.0
# snowballstemmer                2.2.0
# snscrape                       0.4.3.20220106
# sortedcollections              2.1.0
# sortedcontainers               2.4.0
# sounddevice                    0.4.1
# soupsieve                      2.3.1
# Sphinx                         6.1.1
# sphinx-basic-ng                1.0.0b1
# sphinxcontrib-applehelp        1.0.2
# sphinxcontrib-devhelp          1.0.2
# sphinxcontrib-htmlhelp         2.0.0
# sphinxcontrib-jsmath           1.0.1
# sphinxcontrib-qthelp           1.0.3
# sphinxcontrib-serializinghtml  1.1.5
# spyder                         5.1.5
# spyder-kernels                 2.1.3
# SQLAlchemy                     1.4.32
# stack-data                     0.2.0
# statsmodels                    0.13.2
# streamlit                      1.15.2
# sympy                          1.10.1
# tables                         3.6.1
# tabulate                       0.8.9
# TBB                            0.2
# tblib                          1.7.0
# tenacity                       8.0.1
# tensorboard                    2.11.2
# tensorboard-data-server        0.6.1
# tensorboard-plugin-wit         1.8.1
# tensorflow                     2.11.1
# tensorflow-estimator           2.11.0
# tensorflow-intel               2.11.1
# tensorflow-io-gcs-filesystem   0.31.0
# termcolor                      2.2.0
# terminado                      0.13.1
# testpath                       0.5.0
# Note: you may need to restart the kernel to use updated packages.
# text-unidecode                 1.3
# textdistance                   4.2.1
# threadpoolctl                  2.2.0
# three-merge                    0.1.1
# tifffile                       2021.7.2
# tinycss                        0.4
# tldextract                     3.2.0
# toml                           0.10.2
# tomli                          1.2.2
# toolz                          0.11.2
# torch                          1.13.1
# torchvision                    0.14.1
# tornado                        6.1
# tqdm                           4.62.3
# traitlets                      5.1.1
# trio                           0.22.0
# trio-websocket                 0.9.2
# Twisted                        22.2.0
# twisted-iocpsupport            1.0.2
# typed-ast                      1.4.3
# typing_extensions              4.1.1
# tzdata                         2022.6
# tzlocal                        4.2
# ujson                          5.1.0
# Unidecode                      1.2.0
# urllib3                        1.26.7
# validators                     0.20.0
# w3lib                          1.21.0
# watchdog                       2.1.6
# wcwidth                        0.2.5
# webencodings                   0.5.1
# websocket-client               0.58.0
# Werkzeug                       2.0.3
# wheel                          0.37.1
# widgetsnbextension             3.5.2
# win-inet-pton                  1.1.0
# win-unicode-console            0.5
# wincertstore                   0.2
# wordcloud                      1.8.2.2
# wrapt                          1.12.1
# wsproto                        1.2.0
# xarray                         0.20.1
# xlrd                           2.0.1
# XlsxWriter                     3.0.3
# xlwings                        0.24.9
# yapf                           0.31.0
# yarl                           1.6.3
# zict                           2.0.0
# zipp                           3.7.0
# zope.interface                 5.4.0

# %%
print(X.shape)
print(X[0])
# Out:
# (25000, 10, 3)
# [[  1.436 113.    197.   ]
#  [  1.725 116.    197.   ]
#  [  2.144 116.    197.   ]
#  [  2.202 116.    197.   ]
#  [  2.341 116.    166.   ]
#  [  2.449 143.    166.   ]
#  [  6.088 143.    108.   ]
#  [  6.169 107.    108.   ]
#  [  2.656 107.    108.   ]
#  [  2.848 107.    108.   ]]

# %%
print(y.shape)
print(y[0])
# Out:
# (25000,)
# 2.872

# %% [markdown]
# ☝️ The data describes the evolution of the **employment status of a person, year after year**: each sequence corresponds to 10 consecutive years, where each year describes a job situation, comprising of 3 components
# - the salary,
# - the number of persons under one's responsability,
# - the size of the company.
#
# So, from this 25000 sequences, each of 10 consecutive observations, the goal is to predict the salary on the 11th year based on the past observations.

# %% [markdown]
# ❓ **Question** ❓ Take some sequences and plot the evolution of their salaries, of the persons under their responsibility and of the company sizes. You might see some correlation between the three variables.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# YOUR CODE HERE

t = np.arange(0,10)
xs = []; xm = []; xe = []
for i in range (0,4):
    curs = []; curm = []; cure = []
    for ti in t:
        curs.append(X[i][ti][0])
        curm.append(X[i][ti][1])
        cure.append(X[i][ti][2])
    xs.append(curs)
    xm.append(curm)
    xe.append(cure)
    

    fig, ax1 = plt.subplots()
    
    ax2 = ax1.twinx()
    
    ax1.grid()
    ax1.set_xticks(t + 1)
    
    ax1.plot(t + 1, xs[i], color = 'green')
    ax1.tick_params(axis='y', labelcolor='green')
    ax1.set_xlabel('year')
    ax1.set_ylabel('salary (x $1000)', color='green')
    
    ax2.plot(t + 1, xm[i], color = 'red')
    ax2.plot(t + 1, xe[i], color = 'yellow')
    ax2.tick_params(axis='y', labelcolor='orange')
    ax2.set_ylabel('(yellow) size of company,\n(red) # of persons under one\'s responibility', color='orange')
    
    fig.suptitle("Employee [" + str(i) + "]")
    fig.show()
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_11484\2409583518.py:34: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_11484\2409583518.py:34: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_11484\2409583518.py:34: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_11484\2409583518.py:34: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ❓ **Question** ❓ Plot the distribution of all the salaries, persons under one's responsibility, and company sizes to get a better understanding of the variability of observations

# %%
# YOUR CODE HERE

t = np.arange(0,len(X))
xs = []; xm = []; xe = []
for ti in t:
    xs.append(X[ti][0][0])
    xm.append(X[ti][0][1])
    xe.append(X[ti][0][2])
    

fig, ax1 = plt.subplots(figsize=(15, 5))
    
ax2 = ax1.twinx()
    
ax1.grid()

ax1.scatter(t + 1, xs, color = 'green', sizes=[2])
ax1.tick_params(axis='y', labelcolor='green')
ax1.set_xlabel('instance')
ax1.set_ylabel('salary (x $1000)', color='green')

ax2.scatter(t + 1, xe, color = 'yellow', sizes=[2]) 
ax2.scatter(t + 1, xm, color = 'red', sizes=[2])
ax2.tick_params(axis='y', labelcolor='orange')
ax2.set_ylabel('(yellow) size of company,\n(red) # of persons under one\'s responibility', color='orange')

fig.suptitle("Distribution")
fig.show()
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_11484\1493859146.py:28: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ❓ **Question** ❓  Split your dataset between a train and test set (20/80%)

# %%
# YOUR CODE HERE
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.8)

# %% [markdown]
# # 2. A Simple RNN
#
# Now, you will create your first Recurrent Neural Network. Let's start simple
#
# ❓ **Question** ❓ Write a model that has:
# - a `Normalization` layer adapted on the training set
# - a `SimpleRNN` layer with 20 `units` - don't forget to choose the `tanh` activation function
# - a Dense layer with 10 neurons
# - a last Dense layer specific to your task (predict a salary)
#
# Remember, you don't need to specify an `input_shape`: as soon as your normalizer has been adapted to your train set, it has memorized it.

# %%
from keras.layers.normalization import *
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Flatten
from keras import layers

# YOUR CODE HERE
norm = Normalization()
norm.adapt(X_train)
model = Sequential()
#normalization_layer = Normalization()
#normalization_layer.adapt(X_train)
model.add(norm)
model.add(layers.SimpleRNN(units=20, activation="tanh"))
model.add(layers.Dense(10, activation="relu"))
model.add(layers.Dense(1, activation="linear"))

# model.compile(loss='mse', optimizer='rmsprop')
# model.fit(X_train, y_train, batch_size=16, epochs=10, verbose=0)
# model.summary()

# %% [markdown]
# ❓ **Question** ❓ Compute the number of trainable parameters of your model using `model.summary`.
#
# Then, try to recompute them by hand
#
# 💡 Hints:
# - Your `normalization` layer has 7 non-trainable params, which comprise of the mean and standard deviation of each 3 features (salary, persons under responsibility, company size) plus one bias set to 0
#
# - If $\color{green}{n_h}$ RNN units are applied in parallel to $\color{red}{n_x}$ features, the layer has $\color{green}{n_h}(\color{green}{n_h} + \color{red}{n_x} + 1)$ parameters to train. Notice how this number is *independent* of the length of each sequences (here 10 days)

# %%
# YOUR CODE HERE
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization_3 (Normalizat  (None, None, 3)          7
#  ion)
#
#  simple_rnn_4 (SimpleRNN)    (None, 20)                480
#
#  dense_5 (Dense)             (None, 10)                210
#
#  dense_6 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 708
# Trainable params: 701
# Non-trainable params: 7
# _________________________________________________________________

# %% [markdown]
# ❓ **Question** ❓ Compile your model. Remember to first use the `rmsprop` optimizer (instead of Adam).

# %%
# YOUR CODE HERE
model.compile(loss='mse', optimizer='rmsprop')

# %% [markdown]
# ❓ **Question** ❓ Run your model on your data. Use a validation split of 20% and an early stopping criterion (patience=5). Evaluate your performance on the test set

# %%
# YOUR CODE HERE
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)
model.fit(X_train, y_train, batch_size=16, epochs=10, verbose=0, callbacks=[callback])
print(model.predict(X_test))
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001ECA8CEB3A0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001ECA8CEB3A0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 625/625 [==============================] - 1s 1ms/step
# [[ 1.7025099]
#  [ 3.0021484]
#  [21.007906 ]
#  ...
#  [ 4.9701295]
#  [ 4.8016853]
#  [ 2.9733524]]

# %% [markdown]
# # Baseline comparison?
#
#
# In the case of a usual regression model, a baseline prediction for `y_test` could be to predict the average of `y_train`.
#
# With temporal data, it often happens that you try to predict a value that you have already seen in the past: here, the salary. In that case, a baseline model could be to predict for instance that the 11-th salary is equal to the 10-th salary.
#
# ❓ **Question** ❓ Compute the Mean Absolute Error of a model that would predict that the salary remains constant between the 10-th and 11-th year and compare it to your RNN.

# %%
# YOUR CODE HERE
from sklearn.metrics import mean_absolute_error as mae

constant_prediction(X, y)
# Out:
# [0.02400000000000002,
#  0.08700000000000019,
#  0.09799999999999986,
#  0.07499999999999973,
#  0.07600000000000007,
#  0.10099999999999998,
#  20.299,
#  0.121,
#  0.1280000000000001,
#  0.08899999999999997,
#  0.17600000000000016,
#  -0.2669999999999999,
#  0.0129999999999999,
#  0.050000000000000044,
#  0.0900000000000003,
#  0.10799999999999699,
#  0.07000000000000028,
#  0.14900000000000002,
#  0.11500000000000021,
#  0.03300000000000125,
#  0.7999999999999998,
#  0.2470000000000001,
#  0.09800000000000031,
#  0.10200000000000031,
#  0.17499999999999982,
#  0.1499999999999999,
#  0.08300000000000018,
#  0.12600000000000033,
#  0.17500000000000004,
#  0.03500000000000014,
#  0.14800000000000013,
#  0.14699999999999935,
#  0.06199999999999983,
#  0.07899999999999974,
#  -0.09200000000000053,
#  0.0909999999999993,
#  0.13999999999999968,
#  0.1990000000000003,
#  0.22100000000000009,
#  0.10000000000000009,
#  1.0980000000000003,
#  0.21300000000000097,
#  0.04300000000000104,
#  0.18099999999999983,
#  0.01100000000000012,
#  0.06899999999999995,
#  0.08099999999999996,
#  0.052999999999999936,
#  -0.08099999999999996,
#  3.7859999999999996,
#  0.5909999999999997,
#  0.9399999999999995,
#  0.04599999999999982,
#  0.14199999999999946,
#  0.1339999999999999,
#  1.8139999999999998,
#  0.04599999999999982,
#  0.08999999999999986,
#  0.11599999999999966,
#  0.16100000000000003,
#  0.6729999999999998,
#  0.07500000000000018,
#  0.137,
#  0.121,
#  0.0649999999999995,
#  0.12699999999999978,
#  0.016000000000000014,
#  0.133,
#  0.04899999999999993,
#  0.1070000000000011,
#  0.4079999999999999,
#  0.07500000000000018,
#  0.09299999999999997,
#  0.07200000000000006,
#  0.0129999999999999,
#  0.07400000000000007,
#  0.06199999999999983,
#  0.3979999999999997,
#  0.06200000000000028,
#  0.0970000000000002,
#  0.10000000000000009,
#  0.135,
#  0.24099999999999988,
#  0.1999999999999993,
#  0.8930000000000002,
#  0.21799999999999997,
#  0.133,
#  0.14200000000000035,
#  -0.2719999999999998,
#  1.8529999999999998,
#  0.123,
#  0.29800000000000004,
#  0.1509999999999998,
#  0.1259999999999999,
#  0.5349999999999999,
#  0.09799999999999986,
#  0.09399999999999997,
#  0.06099999999999994,
#  0.05699999999999994,
#  0.29100000000000037,
#  0.04100000000000037,
#  0.07000000000000006,
#  0.06499999999999995,
#  0.125,
#  0.41500000000000004,
#  0.1160000000000001,
#  0.052000000000000046,
#  0.09599999999999964,
#  0.1200000000000001,
#  0.09399999999999986,
#  0.1509999999999999,
#  0.06999999999999984,
#  0.14500000000000002,
#  0.29200000000000004,
#  0.07299999999999995,
#  -0.09499999999999997,
#  0.17100000000000026,
#  0.09899999999999975,
#  0.9430000000000005,
#  0.040000000000000036,
#  0.06800000000000006,
#  0.13800000000000012,
#  0.03399999999999981,
#  0.10099999999999998,
#  0.13400000000000034,
#  0.11699999999999999,
#  2.329,
#  0.09200000000000008,
#  0.04899999999999993,
#  0.04700000000000015,
#  0.02699999999999969,
#  0.09999999999999964,
#  1.2720000000000002,
#  0.12300000000000111,
#  0.0860000000000003,
#  0.13299999999999912,
#  0.9939999999999998,
#  0.04600000000000026,
#  0.10899999999999999,
#  0.17900000000000005,
#  0.05099999999999971,
#  2.9139999999999997,
#  1.0939999999999999,
#  0.13400000000000034,
#  0.11400000000000077,
#  0.3460000000000001,
#  0.04899999999999949,
#  0.24099999999999966,
#  0.21900000000000008,
#  14.86,
#  0.1549999999999998,
#  0.09200000000000008,
#  0.14700000000000024,
#  0.040000000000000036,
#  -0.13600000000000012,
#  0.1419999999999999,
#  0.08299999999999996,
#  0.0,
#  0.15399999999999991,
#  0.14200000000000035,
#  0.09899999999999975,
#  0.06299999999999972,
#  1.1320000000000001,
#  -1.917,
#  0.07700000000000173,
#  1.5,
#  0.121,
#  0.051000000000000156,
#  0.08899999999999997,
#  0.1549999999999998,
#  0.07500000000000018,
#  2.4450000000000003,
#  -5.4239999999999995,
#  0.46799999999999997,
#  0.13100000000000023,
#  0.08199999999999985,
#  0.07299999999999995,
#  0.07100000000000017,
#  0.14500000000000002,
#  0.04499999999999993,
#  0.137,
#  0.0779999999999994,
#  0.14400000000000013,
#  0.16000000000000014,
#  0.07200000000000006,
#  0.057000000000000384,
#  -0.054999999999999716,
#  0.121,
#  0.0770000000000004,
#  0.3599999999999999,
#  0.8619999999999999,
#  0.2509999999999999,
#  3.378999999999998,
#  0.07399999999999984,
#  0.0040000000000000036,
#  0.04299999999999926,
#  0.1339999999999999,
#  1.558,
#  0.09600000000000009,
#  0.05500000000000016,
#  0.026000000000000245,
#  0.1180000000000001,
#  0.843,
#  0.05899999999999994,
#  1.9380000000000024,
#  -0.041999999999999815,
#  0.041999999999999815,
#  0.08400000000000007,
#  0.1279999999999999,
#  2.2940000000000005,
#  0.1160000000000001,
#  0.12400000000000011,
#  0.13,
#  0.891,
#  0.10599999999999987,
#  1.0110000000000001,
#  0.11699999999999999,
#  0.07499999999999973,
#  0.17300000000000004,
#  0.1429999999999998,
#  -0.256,
#  0.09299999999999997,
#  0.09299999999999997,
#  0.16400000000000015,
#  0.3380000000000001,
#  0.08400000000000007,
#  0.0349999999999997,
#  0.125,
#  0.10300000000000153,
#  0.06699999999999995,
#  0.02100000000000013,
#  0.22999999999999998,
#  -0.016000000000000014,
#  1.0660000000000007,
#  0.06099999999999994,
#  0.07299999999999995,
#  0.13999999999999968,
#  0.1080000000000001,
#  -0.6909999999999998,
#  0.03799999999999981,
#  0.10000000000000053,
#  0.008000000000000007,
#  0.07600000000000007,
#  0.391,
#  1.6969999999999996,
#  0.08300000000000196,
#  0.14499999999999957,
#  0.05899999999999994,
#  0.038000000000000256,
#  1.3390000000000004,
#  0.03800000000000381,
#  0.08700000000000019,
#  0.11799999999999988,
#  0.07299999999999995,
#  0.04800000000000004,
#  0.08600000000000008,
#  0.12399999999999967,
#  0.125,
#  0.3760000000000012,
#  -0.004999999999999893,
#  0.11000000000000032,
#  0.136000000000001,
#  0.16599999999999993,
#  19.688000000000002,
#  0.06499999999999995,
#  1.3409999999999997,
#  3.396000000000001,
#  0.278,
#  0.028000000000000025,
#  0.09800000000000075,
#  0.13000000000000078,
#  -0.8620000000000001,
#  -0.20299999999999985,
#  0.45300000000000007,
#  0.0519999999999996,
#  -6.37,
#  0.3400000000000001,
#  0.13500000000000023,
#  4.1770000000000005,
#  0.04499999999999993,
#  1.5359999999999996,
#  0.6379999999999999,
#  0.17600000000000016,
#  5.988,
#  0.019000000000000128,
#  0.08800000000000008,
#  0.1120000000000001,
#  2.997,
#  -0.05900000000000016,
#  0.07500000000000018,
#  0.15899999999999892,
#  0.6760000000000002,
#  0.06499999999999995,
#  0.121,
#  1.4489999999999998,
#  -0.0129999999999999,
#  0.7969999999999997,
#  0.07599999999999962,
#  0.1719999999999997,
#  0.09799999999999986,
#  0.04999999999999982,
#  2.5580000000000003,
#  0.10099999999999998,
#  -0.027000000000000135,
#  0.1479999999999999,
#  -3.4209999999999994,
#  0.05700000000000016,
#  4.297999999999998,
#  0.17600000000000016,
#  0.08000000000000007,
#  8.391,
#  0.4359999999999995,
#  0.08000000000000007,
#  2.746000000000002,
#  0.16800000000000015,
#  0.0860000000000003,
#  0.01200000000000001,
#  0.10599999999999987,
#  0.04400000000000004,
#  0.7329999999999997,
#  -0.12400000000000055,
#  0.051000000000000156,
#  0.06499999999999995,
#  0.08599999999999985,
#  0.008000000000000007,
#  0.1639999999999997,
#  0.10999999999999988,
#  1.511,
#  0.14500000000000002,
#  0.11899999999999977,
#  0.10199999999999987,
#  0.919,
#  2.8970000000000002,
#  0.11800000000000033,
#  0.18399999999999972,
#  0.27000000000000046,
#  -0.9370000000000012,
#  0.2030000000000003,
#  2.5450000000000004,
#  0.09099999999999997,
#  0.09600000000000009,
#  0.13900000000000023,
#  0.07899999999999996,
#  0.008000000000000007,
#  0.058999999999999275,
#  0.1429999999999998,
#  0.10200000000000009,
#  -7.145,
#  0.12400000000000011,
#  0.06899999999999995,
#  0.06499999999999995,
#  -0.238,
#  1.1020000000000003,
#  0.21300000000000008,
#  0.18900000000000006,
#  0.06699999999999995,
#  0.2120000000000002,
#  0.2909999999999999,
#  0.04899999999999993,
#  0.4830000000000001,
#  0.06500000000000039,
#  0.41999999999999993,
#  0.06699999999999995,
#  0.04499999999999993,
#  0.16999999999999993,
#  0.02300000000000013,
#  0.08800000000000008,
#  0.09500000000000242,
#  0.2709999999999999,
#  0.635,
#  0.09200000000000008,
#  0.133,
#  0.15799999999999992,
#  0.04300000000000015,
#  3.910999999999998,
#  0.03499999999999992,
#  0.16599999999999993,
#  0.10999999999999988,
#  0.02499999999999991,
#  0.11299999999999999,
#  0.08899999999999997,
#  2.6240000000000006,
#  0.09100000000000019,
#  -0.020999999999999908,
#  0.12200000000000033,
#  0.10899999999999999,
#  0.32999999999999985,
#  0.009999999999999787,
#  0.11099999999999977,
#  0.10199999999999987,
#  0.2160000000000002,
#  -0.01100000000000001,
#  0.1559999999999997,
#  -1.38,
#  0.14000000000000012,
#  0.14300000000000068,
#  0.16500000000000004,
#  2.8069999999999986,
#  0.10999999999999988,
#  0.17300000000000004,
#  -0.10800000000000054,
#  1.069,
#  0.1589999999999998,
#  0.15200000000000014,
#  0.5619999999999998,
#  -0.41900000000000004,
#  1.2409999999999997,
#  0.1620000000000026,
#  8.017000000000001,
#  0.16400000000000015,
#  0.14400000000000013,
#  0.05499999999999994,
#  0.07499999999999996,
#  0.02400000000000002,
#  0.08999999999999986,
#  0.18299999999999983,
#  2.832,
#  0.11400000000000077,
#  0.23500000000000032,
#  -0.03699999999999992,
#  0.20899999999999963,
#  0.07099999999999995,
#  0.0860000000000003,
#  0.10999999999999988,
#  0.07099999999999973,
#  0.4969999999999999,
#  0.038000000000000256,
#  2.785,
#  0.14200000000000035,
#  0.17799999999999905,
#  0.5299999999999998,
#  0.18900000000000006,
#  0.05699999999999994,
#  0.10899999999999999,
#  0.07500000000000018,
#  1.8900000000000006,
#  0.040000000000000036,
#  0.09700000000000131,
#  0.08600000000000008,
#  0.13299999999999912,
#  0.1599999999999997,
#  0.03500000000000014,
#  0.006000000000000227,
#  0.020999999999999908,
#  0.08199999999999985,
#  0.12300000000000111,
#  0.11100000000000021,
#  0.10499999999999865,
#  0.1479999999999999,
#  0.30900000000000016,
#  0.11099999999999999,
#  0.10599999999999987,
#  2.5729999999999995,
#  0.13999999999999968,
#  0.050999999999999934,
#  0.09299999999999997,
#  7.379999999999999,
#  0.33099999999999996,
#  1.605,
#  0.19700000000000006,
#  0.10099999999999998,
#  0.11100000000000021,
#  0.13599999999999923,
#  0.1140000000000001,
#  0.04200000000000004,
#  0.11699999999999999,
#  0.16500000000000004,
#  0.10099999999999998,
#  0.21199999999999974,
#  0.15899999999999892,
#  0.16700000000000004,
#  0.03699999999999992,
#  0.1440000000000019,
#  0.17200000000000015,
#  0.09899999999999998,
#  1.1229999999999993,
#  4.967,
#  0.6719999999999988,
#  0.05799999999999983,
#  -0.03399999999999981,
#  0.5689999999999991,
#  0.15500000000000025,
#  0.15199999999999925,
#  0.15699999999999958,
#  0.04700000000000015,
#  0.08499999999999996,
#  0.1379999999999999,
#  0.10999999999999943,
#  1.2290000000000005,
#  0.11599999999999966,
#  0.19699999999999962,
#  0.6320000000000006,
#  0.14400000000000013,
#  0.21700000000000008,
#  -0.9860000000000001,
#  0.10400000000000098,
#  0.016999999999999904,
#  0.3880000000000001,
#  0.1509999999999998,
#  0.1070000000000002,
#  1.8330000000000002,
#  0.7829999999999995,
#  0.10099999999999998,
#  0.06999999999999995,
#  4.952999999999999,
#  0.04899999999999993,
#  -0.028000000000000025,
#  1.2110000000000003,
#  0.1459999999999999,
#  0.0990000000000002,
#  0.126,
#  0.17999999999999994,
#  9.875,
#  0.06099999999999994,
#  -0.10499999999999998,
#  0.15700000000000003,
#  0.11099999999999999,
#  0.12400000000000011,
#  0.0259999999999998,
#  0.06999999999999984,
#  -0.014000000000000234,
#  0.1259999999999999,
#  0.7560000000000002,
#  0.12400000000000011,
#  -0.018000000000000238,
#  0.050000000000000266,
#  0.09299999999999997,
#  0.040000000000000036,
#  0.15100000000000002,
#  0.10299999999999998,
#  0.1599999999999997,
#  0.07600000000000007,
#  0.1339999999999999,
#  0.050999999999999934,
#  0.028000000000000025,
#  0.11400000000000032,
#  0.1379999999999999,
#  -3.764000000000001,
#  -0.014000000000001123,
#  2.652000000000001,
#  0.11399999999999988,
#  0.02699999999999969,
#  0.19999999999999973,
#  0.6199999999999999,
#  0.10000000000000009,
#  0.09899999999999998,
#  0.10499999999999998,
#  0.32099999999999995,
#  0.04600000000000115,
#  -0.028000000000000025,
#  0.8140000000000001,
#  0.37599999999999945,
#  0.20800000000000018,
#  0.07099999999999973,
#  0.040999999999999925,
#  0.1379999999999999,
#  0.021999999999998465,
#  0.06099999999999994,
#  0.07099999999999973,
#  0.1419999999999999,
#  0.21399999999999997,
#  1.2769999999999997,
#  1.9640000000000002,
#  0.3190000000000004,
#  0.08699999999999974,
#  0.23599999999999977,
#  0.133,
#  7.162,
#  0.14900000000000002,
#  0.09200000000000008,
#  0.06199999999999983,
#  1.2159999999999993,
#  0.3740000000000001,
#  -0.006000000000000227,
#  0.13399999999999945,
#  0.1100000000000001,
#  1.123000000000001,
#  0.10599999999999987,
#  -0.7419999999999991,
#  0.09600000000000009,
#  0.1479999999999999,
#  -0.029999999999999805,
#  0.2180000000000002,
#  0.09699999999999998,
#  0.13700000000000045,
#  0.08599999999999985,
#  0.16100000000000003,
#  0.6399999999999997,
#  0.0860000000000003,
#  0.1670000000000016,
#  5.584,
#  0.040000000000000036,
#  0.10699999999999976,
#  0.11400000000000032,
#  -4.3919999999999995,
#  0.07099999999999995,
#  0.08499999999999996,
#  0.09600000000000009,
#  0.16699999999999982,
#  0.14500000000000002,
#  0.129,
#  0.16000000000000014,
#  0.10000000000000009,
#  0.7029999999999994,
#  0.2629999999999999,
#  0.20299999999999985,
#  0.1070000000000002,
#  0.17900000000000027,
#  0.08900000000000019,
#  0.0589999999999975,
#  2.678,
#  0.11699999999999999,
#  0.14700000000000024,
#  -0.0039999999999995595,
#  0.1080000000000001,
#  0.5799999999999998,
#  0.11700000000000088,
#  0.09200000000000008,
#  -0.16900000000000004,
#  1.286,
#  0.08099999999999996,
#  0.16599999999999993,
#  4.799,
#  2.162,
#  0.04200000000000004,
#  0.1720000000000006,
#  0.1639999999999997,
#  0.36599999999999966,
#  2.661,
#  0.07799999999999985,
#  0.10599999999999987,
#  0.09700000000000042,
#  5.1899999999999995,
#  0.32699999999999996,
#  0.14500000000000046,
#  0.17300000000000004,
#  4.686,
#  0.07300000000000006,
#  0.06699999999999973,
#  0.07899999999999996,
#  0.1639999999999997,
#  1.2349999999999999,
#  0.12799999999999967,
#  0.1490000000000009,
#  0.002000000000000224,
#  0.07899999999999996,
#  0.09200000000000008,
#  0.10200000000000031,
#  0.4079999999999999,
#  0.05600000000000005,
#  0.13600000000000012,
#  0.13900000000000023,
#  0.10899999999999999,
#  0.22199999999999953,
#  0.08899999999999997,
#  0.12400000000000055,
#  0.07600000000000051,
#  0.10200000000000031,
#  0.22699999999999987,
#  0.139,
#  -0.006000000000000227,
#  0.19799999999999995,
#  -0.17099999999999937,
#  0.07000000000000028,
#  0.2970000000000006,
#  2.248,
#  0.04899999999999993,
#  1.053,
#  0.0519999999999996,
#  0.4320000000000004,
#  0.12600000000000033,
#  0.4979999999999998,
#  0.1200000000000001,
#  0.11099999999999977,
#  0.19700000000000006,
#  6.084,
#  0.09799999999999998,
#  -0.016000000000000014,
#  0.1649999999999998,
#  -0.06200000000000028,
#  0.1639999999999997,
#  -2.2669999999999995,
#  -0.008000000000000007,
#  2.7090000000000005,
#  -0.14500000000000002,
#  0.06499999999999995,
#  0.9459999999999997,
#  0.11500000000000021,
#  0.0259999999999998,
#  0.09199999999999986,
#  0.06400000000000006,
#  0.1769999999999996,
#  0.15200000000000014,
#  0.15600000000000058,
#  0.11099999999999977,
#  0.19399999999999995,
#  0.16400000000000015,
#  0.46000000000000085,
#  0.06099999999999994,
#  -4.238000000000003,
#  -0.0030000000000001137,
#  0.10200000000000031,
#  8.176,
#  0.1589999999999998,
#  0.0820000000000003,
#  -0.010000000000000231,
#  0.16700000000000026,
#  0.06200000000000028,
#  0.06099999999999994,
#  0.1309999999999999,
#  0.16999999999999993,
#  0.09599999999999964,
#  0.11499999999999977,
#  -0.7170000000000001,
#  0.11799999999999988,
#  4.531000000000001,
#  0.31400000000000006,
#  0.2559999999999998,
#  0.23599999999999977,
#  0.14100000000000001,
#  0.10099999999999998,
#  0.133,
#  7.57,
#  0.12400000000000011,
#  0.08199999999999985,
#  0.18999999999999995,
#  -0.18599999999999994,
#  1.618000000000002,
#  8.259999999999998,
#  0.06500000000000006,
#  0.21900000000000008,
#  0.052000000000000046,
#  0.1549999999999998,
#  1.2320000000000002,
#  0.14900000000000002,
#  0.08099999999999996,
#  0.15200000000000014,
#  0.15599999999999992,
#  2.3369999999999997,
#  0.14100000000000001,
#  0.13500000000000023,
#  0.1339999999999999,
#  4.007,
#  0.041999999999999815,
#  -0.21699999999999986,
#  0.1589999999999998,
#  3.9749999999999996,
#  0.10199999999999987,
#  0.0860000000000003,
#  0.12600000000000033,
#  0.14400000000000013,
#  0.07800000000000029,
#  -4.587,
#  0.0649999999999995,
#  0.127,
#  -0.04800000000000004,
#  -0.002000000000000224,
#  0.07599999999999962,
#  0.13200000000000012,
#  0.03600000000000003,
#  0.06400000000000006,
#  0.018000000000000016,
#  0.17600000000000016,
#  0.17900000000000027,
#  -0.16300000000000026,
#  0.07699999999999996,
#  0.6800000000000002,
#  0.028000000000000025,
#  2.8419999999999996,
#  0.02999999999999936,
#  0.07699999999999996,
#  0.16199999999999992,
#  0.133,
#  0.04200000000000004,
#  -1.81,
#  0.9550000000000001,
#  0.2610000000000001,
#  0.10099999999999998,
#  0.1339999999999999,
#  3.2119999999999997,
#  -6.786,
#  0.08300000000000018,
#  -0.15799999999999992,
#  -0.43299999999999983,
#  0.06200000000000028,
#  0.05000000000000071,
#  0.05600000000000005,
#  0.129,
#  0.07200000000000006,
#  0.051000000000000156,
#  2.2569999999999997,
#  -2.4110000000000005,
#  0.08400000000000007,
#  0.14300000000000024,
#  1.2620000000000005,
#  0.18200000000000038,
#  0.06799999999999962,
#  0.06499999999999995,
#  0.07699999999999996,
#  0.10999999999999988,
#  0.6639999999999999,
#  0.040999999999999925,
#  0.045999999999999375,
#  0.15799999999999992,
#  10.943999999999999,
#  0.1060000000000001,
#  0.10300000000000153,
#  -0.004999999999999893,
#  0.09499999999999886,
#  0.04800000000000004,
#  0.06700000000000017,
#  0.06699999999999973,
#  1.8819999999999997,
#  0.1259999999999999,
#  0.0860000000000003,
#  0.03600000000000003,
#  0.11100000000000021,
#  0.1519999999999999,
#  0.19999999999999973,
#  0.21300000000000008,
#  0.2310000000000001,
#  0.17900000000000027,
#  0.08099999999999952,
#  0.0129999999999999,
#  0.12299999999999978,
#  0.09299999999999997,
#  2.4720000000000004,
#  0.07699999999999996,
#  0.08800000000000008,
#  0.258,
#  0.14500000000000002,
#  0.11300000000000043,
#  0.05699999999999994,
#  0.09600000000000009,
#  0.06799999999999962,
#  -7.643999999999999,
#  0.11399999999999988,
#  0.03200000000000003,
#  0.1279999999999999,
#  0.15600000000000014,
#  0.09899999999999998,
#  -0.19700000000000006,
#  0.9119999999999999,
#  0.1070000000000002,
#  -0.04699999999999993,
#  0.1510000000000007,
#  0.04600000000000004,
#  -2.5380000000000003,
#  0.06099999999999994,
#  -0.026999999999999247,
#  0.05799999999999983,
#  0.1169999999999991,
#  0.12699999999999978,
#  0.06099999999999994,
#  0.12700000000000022,
#  1.6059999999999999,
#  0.54,
#  0.08399999999999985,
#  0.08099999999999996,
#  0.18699999999999983,
#  0.04499999999999993,
#  0.2410000000000032,
#  -0.1509999999999998,
#  0.1620000000000026,
#  -1.854,
#  0.15600000000000014,
#  0.1200000000000001,
#  0.5039999999999996,
#  0.062000000000000055,
#  0.129,
#  0.19199999999999995,
#  0.08800000000000008,
#  0.13600000000000012,
#  0.11000000000000032,
#  0.038000000000000034,
#  -0.1120000000000001,
#  0.08899999999999997,
#  0.002000000000000224,
#  3.808,
#  0.028000000000000025,
#  0.14400000000000013,
#  0.05499999999999994,
#  0.11100000000000021,
#  0.6180000000000001,
#  0.03500000000000014,
#  0.18200000000000016,
#  0.07400000000000162,
#  0.08099999999999996,
#  0.23799999999999955,
#  0.10099999999999998,
#  0.10299999999999998,
#  -3.792,
#  0.135,
#  0.17100000000000004,
#  0.08599999999999941,
#  0.14500000000000002,
#  0.007000000000000117,
#  -6.063000000000001,
#  0.6299999999999999,
#  0.0259999999999998,
#  0.9429999999999996,
#  1.8010000000000002,
#  0.07499999999999973,
#  0.09699999999999998,
#  0.29899999999999993,
#  0.20000000000000018,
#  0.03399999999999892,
#  0.18900000000000006,
#  0.17099999999999982,
#  1.8399999999999999,
#  0.11099999999999999,
#  0.7779999999999987,
#  0.11299999999999977,
#  -2.6439999999999997,
#  0.08000000000000007,
#  0.07099999999999973,
#  0.387,
#  0.10499999999999998,
#  0.05499999999999994,
#  0.3100000000000005,
#  0.10899999999999999,
#  0.0259999999999998,
#  0.1739999999999995,
#  4.911,
#  0.16500000000000004,
#  0.08499999999999996,
#  1.152000000000001,
#  0.238,
#  0.17300000000000004,
#  0.1459999999999999,
#  0.5329999999999999,
#  2.3190000000000004,
#  0.053999999999998494,
#  0.12400000000000011,
#  0.12700000000000022,
#  0.09999999999999987,
#  0.1389999999999998,
#  0.09200000000000008,
#  0.08599999999999985,
#  -0.19199999999999995,
#  0.18399999999999994,
#  0.1379999999999999,
#  0.13999999999999968,
#  0.09699999999999998,
#  0.15400000000000036,
#  0.0909999999999993,
#  0.010000000000000009,
#  0.04599999999999982,
#  0.08499999999999996,
#  0.09600000000000009,
#  0.1200000000000001,
#  0.17900000000000027,
#  0.7969999999999999,
#  0.14400000000000013,
#  0.008999999999999897,
#  0.137,
#  0.0730000000000004,
#  0.09600000000000009,
#  18.843,
#  -2.815999999999999,
#  0.22999999999999998,
#  0.12299999999999933,
#  1.0439999999999998,
#  0.41800000000000015,
#  0.22100000000000009,
#  0.10599999999999987,
#  -0.0039999999999995595,
#  0.11399999999999899,
#  0.0,
#  -0.04200000000000026,
#  3.3070000000000004,
#  -0.026000000000003354,
#  0.17300000000000004,
#  0.4660000000000002,
#  0.038000000000000256,
#  0.1589999999999998,
#  0.055000000000000604,
#  0.08300000000000018,
#  0.14000000000000057,
#  0.07100000000000017,
#  0.12400000000000011,
#  0.02099999999999902,
#  0.19700000000000006,
#  0.1160000000000001,
#  0.1160000000000001,
#  -0.18799999999999972,
#  0.05900000000000016,
#  0.09200000000000053,
#  0.07899999999999974,
#  0.08800000000000008,
#  0.05400000000000005,
#  0.02299999999999991,
#  0.125,
#  0.17300000000000004,
#  -0.030000000000000027,
#  0.06100000000000039,
#  0.16900000000000048,
#  0.1419999999999999,
#  1.2029999999999994,
#  0.08099999999999996,
#  ...]

# %%
np.mean(np.abs(error))
# Out:
# 0.58259132

# %%
def constant_prediction(X, y):
    error = []
    for xx, yy in zip(X, y):
        last_salary = xx[-1][0]
        error.append(yy - last_salary)

    return error

error = constant_prediction(X, y)

# %% [markdown]
# You have probably seen that your prediction is a little bit better than the baseline model
#
# # LSTM
#
# ❓ **Question** ❓ Write the exact same model, but with a `LSTM` instead of a `SimpleRNN` and evaluate your performance on the test set

# %%
from keras.layers.normalization import *
from keras.models import Sequential
from keras.layers import Dense, LSTM, Flatten
from keras import layers

# YOUR CODE HERE
norm = Normalization()
norm.adapt(X_train)
model = Sequential()
#normalization_layer = Normalization()
#normalization_layer.adapt(X_train)
model.add(norm)
model.add(layers.LSTM(units=20, activation="tanh"))
model.add(layers.Dense(10, activation="relu"))
model.add(layers.Dense(1, activation="linear"))

model.summary()
model.compile(loss='mse', optimizer='rmsprop', metrics=["mae"])
model.fit(X_train, y_train, batch_size=16, epochs=10, verbose=0)
model.predict(X_test)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization_9 (Normalizat  (None, None, 3)          7
#  ion)
#
#  lstm_5 (LSTM)               (None, 20)                1920
#
#  dense_17 (Dense)            (None, 10)                210
#
#  dense_18 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 2,148
# Trainable params: 2,141
# Non-trainable params: 7
# _________________________________________________________________
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001ECB1A115E0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ('self',)
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001ECB1A115E0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ('self',)
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001ECB19B6940> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001ECB19B6940> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 625/625 [==============================] - 2s 2ms/step
# array([[ 1.8593271],
#        [ 3.113016 ],
#        [19.31539  ],
#        ...,
#        [ 4.8109207],
#        [ 4.8418245],
#        [ 3.0305521]], dtype=float32)

# %%
model.evaluate(X_test, y_test)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001ECB45F4820> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001ECB45F4820> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 625/625 [==============================] - 2s 2ms/step - loss: 0.9429 - mae: 0.3569
# [0.9428785443305969, 0.3568706512451172]

# %% [markdown]
# ## 🏁 Congratulation
#
# You now know how to run RNN on sequence data!
#
# Note: The sequences you worked with are totally fake. In case you need to train and reproduce similar data, you can find bellow the functions that have been used to simulate this data.

# %% [markdown]
# # Utils (for reference only)

# %%
def create_sequences(number):
    X, y = [], []
    
    for i in range(number):
        x_i, y_i = create_individual_sequence(10)
        X.append(x_i)
        y.append(y_i)
        
    return np.array(X), np.array(y)
            
def create_individual_sequence(length):
    company_sizes = []
    nb_persons = []
    salaries = []
    
    
    # Education level
    educ_level = [max(0, int(np.random.normal(10, 2)))]*length
    
    # Company size
    current_size = int(1 + np.random.beta(.4, 4)*500)
    for i in range(length):
        if not np.random.randint(4): # Change 1 out of 3 possibilities 
            current_size = int(max(1, np.random.normal(current_size, 50)))
        company_sizes.append(current_size)
    
    # Number of persons
    nb_iter = np.random.beta(.15, 4)*300
    for i in range(length):
        if not np.random.randint(2): # Change 1 out of 2 possibilities
            R_1 = np.random.beta(0.5, 8)*3
            nb_iter = nb_iter + max(-2, R_1*company_sizes[i] + np.random.randint(-2, 2))
            nb_iter = max(0, nb_iter)
            nb_iter = int(min(company_sizes[i]-1, nb_iter))
        nb_persons.append(nb_iter)
        
    
    # Salary
    salary_iter = max(800, int(np.random.normal(1200, 300)+ 0.05*company_sizes[0] +  np.random.normal(40, 400)))
    salaries.append(salary_iter)
    for i in range(1, length + 1):
        R_1 = np.random.normal(100, 50)
        change_person = nb_persons[i-1] - nb_persons[i-2]
        change_company = max(0, company_sizes[i-1] - company_sizes[i-2])
        salary_iter = salary_iter + 0.05*change_company + change_person*R_1 + np.random.normal(100, 50)
        salary_iter = max(int(salary_iter), 500)
        
        salaries.append(salary_iter)

    y = salaries[-1]/1000
    salaries = [_/1000 for _ in salaries[:-1]]
    
    return np.array([salaries, nb_persons, company_sizes]).T, y

# %%
#X, y = create_sequences(25000)

#np.save('X', X.astype(np.float32))
#np.save('y', y)
